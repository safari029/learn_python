# %% [markdown]
# # requests
#
# API等を叩く際に必須のhttp通信を直感的に実施できるモジュールです。
# 昔はurllib,urlib2といったものを使ってました。
#
# [Requests: 人間のためのHTTP](http://requests-docs-ja.readthedocs.io/en/latest/)

# %%
import requests

#getの場合
response=requests.get('http://www.nttpc.co.jp')
print(response)
# Out:
# <Response [200]>

# %%
html=response.text.encode(response.encoding)
print(html)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ja">\n<head>\n<meta http-equiv="Content-Type" content="application/xhtml+xml; charset=utf-8" />\n<title>\xe3\x80\x90\xe5\x85\xac\xe5\xbc\x8f\xe3\x80\x91NTTPC\xe3\x82\xb3\xe3\x83\x9f\xe3\x83\xa5\xe3\x83\x8b\xe3\x82\xb1\xe3\x83\xbc\xe3\x82\xb7\xe3\x83\xa7\xe3\x83\xb3\xe3\x82\xba</title>\n<meta name="Description" content="NTTPC\xe3\x82\xb3\xe3\x83\x9f\xe3\x83\xa5\xe3\x83\x8b\xe3\x82\xb1\xe3\x83\xbc\xe3\x82\xb7\xe3\x83\xa7\xe3\x83\xb3\xe3\x82\xba\xe3\x81\xaf\xe3\x80\x81IoT" />\n<meta name="Keywords" content="NTTPC\xe3\x82\xb3\xe3\x83\x9f\xe3\x83\xa5\xe3\x83\x8b\xe3\x82\xb1\xe3\x83\xbc\xe3\x82\xb7\xe3\x83\xa7\xe3\x83\xb3\xe3\x82\xba,IoT,\xe3\x82\xaf\xe3\x83\xa9\xe3\x82\xa6\xe3\x83\x89\xe5\x9f\xba\xe7\x9b\xa4,\xe3\x83\xa2\xe3\x83\x90\xe3\x82\xa4\xe3\x83\xab,\xe3\x83\x8d\xe3\x83\x83\xe3\x83\x88\xe3\x83\xaf\xe3\x83\xbc\xe3\x82\xaf,\xe3\x82\xbb\xe3\x82\xad\xe3\x83\xa5\xe3\x83\xaa\xe3\x83\x86\xe3\x82\xa3" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\t<meta name="Slurp" content="NOYDIR" />\n\t<meta name="viewport" content="width=1080" />\n\t<meta http-equiv="Content-Script-Type" content="text/javascript" />\n\t<meta http-equiv="Content-Style-Type" content="text/css" />\n\t<link rel="stylesheet" type="text/css" media="all" href="/common2/css/base.css" />\n\t<link rel="stylesheet" type="text/css" media="all" href="/common2/css/class.css" />\n\t<link rel="stylesheet" type="text/css" media="print" href="/common2/css/print.css" />\n\t<link rel="shortcut icon" href="/common2/img/favicon.ico" />\n<link rel="stylesheet" type="text/css" media="all" href="/common2/js/slick/slick.css" />\n<link rel="stylesheet" type="text/css" media="all" href="/common2/js/slick/slick-theme.css" />\n<link rel="stylesheet" type="text/css" media="all" href="/css/style.css" />\n</head>\n<body>\n<!-- Google Tag Manager -->\r\n<noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-K4CTCT"\r\n height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\r\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\r\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\r\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\r\n\'//www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\r\n})(window,document,\'script\',\'dataLayer\',\'GTM-K4CTCT\');</script>\r\n<!-- End Google Tag Manager -->\r\n<div id="header">\r\n\t<div class="inner">\r\n\t\t<a href="http://www.nttpc.co.jp/" id="head_logo" class="bg_img">NTT PC Communications</a>\r\n ...

# %%
#辞書型の説明
d={'key1':'param1','key2':'param2'} #辞書型は「キー:値」のセットをカンマ区切りで記述できる
d['key3']='param3' #新たなキーと対応する値を入力すれば追加も可能
print(type(d))
print(d)
# Out:
# <class 'dict'>
# {'key1': 'param1', 'key2': 'param2', 'key3': 'param3'}

# %%
#パラメータん渡し方

d={'key':'param1'}
response=requests.get('http://example.com/',params=d) #http://example.com?key1=param1 といったgetリクエストを出している
response.status_code
# Out:
# 200

# %%
#post

d={'key':'param1'}
response=requests.post('http://example.com/',params=d) #http://example.com?key1=param1 といったgetリクエストを出している
response.status_code
# Out:
# 200

# %% [markdown]
# ## 実践編
# Slack API使ってSlackにメッセージを送信してみましょう。
# [参考: Slack APIでメッセージ送信](http://qiita.com/mizuki_takahashi/items/3f77c2e5b6142563ce66)
